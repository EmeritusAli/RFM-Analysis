# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data = pd.read_csv("data/sales_data_sample.csv", sep=",", encoding='Latin-1')

# %%
data.head(10).T
# Out:
#                                         0                   1  \
# ORDERNUMBER                         10107               10121
# QUANTITYORDERED                        30                  34
# PRICEEACH                            95.7               81.35
# ORDERLINENUMBER                         2                   5
# SALES                              2871.0              2765.9
# ORDERDATE                  2/24/2003 0:00       5/7/2003 0:00
# STATUS                            Shipped             Shipped
# QTR_ID                                  1                   2
# MONTH_ID                                2                   5
# YEAR_ID                              2003                2003
# PRODUCTLINE                   Motorcycles         Motorcycles
# MSRP                                   95                  95
# PRODUCTCODE                      S10_1678            S10_1678
# CUSTOMERNAME            Land of Toys Inc.  Reims Collectables
# PHONE                          2125557818          26.47.1555
# ADDRESSLINE1      897 Long Airport Avenue  59 rue de l'Abbaye
# ADDRESSLINE2                          NaN                 NaN
# CITY                                  NYC               Reims
# STATE                                  NY                 NaN
# POSTALCODE                          10022               51100
# COUNTRY                               USA              France
# TERRITORY                             NaN                EMEA
# CONTACTLASTNAME                        Yu             Henriot
# CONTACTFIRSTNAME                     Kwai                Paul
# DEALSIZE                            Small               Small
#
#                                               2                   3  \
# ORDERNUMBER                               10134               10145
# QUANTITYORDERED                              41                  45
# PRICEEACH                                 94.74               83.26
# ORDERLINENUMBER                               2                   6
# SALES                                   3884.34              3746.7
# ORDERDATE                         7/1/2003 0:00      8/25/2003 0:00
# STATUS                                  Shipped             Shipped
# QTR_ID                                        3                   3
# MONTH_ID                                      7                   8
# YEAR_ID                                    2003                2003
# PRODUCTLINE                         Motorcycles         Motorcycles
# MSRP                                         95                  95
# PRODUCTCODE                            S10_1678            S10_1678
# CUSTOMERNAME                    Lyon Souveniers   Toys4GrownUps.com
# PHONE                          +33 1 46 62 7555          6265557265
# ADDRESSLINE1      27 rue du Colonel Pierre Avia  78934 Hillside Dr.
# ADDRESSLINE2                                NaN                 NaN
# CITY                                      Paris            Pasadena
# STATE                                       NaN                  CA
# POSTALCODE                                75508               90003
# COUNTRY                                  France                 USA
# TERRITORY                                  EMEA                 NaN
# CONTACTLASTNAME                        Da Cunha               Young
# CONTACTFIRSTNAME                         Daniel               Julie
# DEALSIZE                                 Medium              Medium
#
#                                          4                     5  \
# ORDERNUMBER                          10159                 10168
# QUANTITYORDERED                         49                    36
# PRICEEACH                            100.0                 96.66
# ORDERLINENUMBER                         14                     1
# SALES                              5205.27               3479.76
# ORDERDATE                  10/10/2003 0:00       10/28/2003 0:00
# STATUS                             Shipped               Shipped
# QTR_ID                                   4                     4
# MONTH_ID                                10                    10
# YEAR_ID                               2003                  2003
# PRODUCTLINE                    Motorcycles           Motorcycles
# MSRP                                    95                    95
# PRODUCTCODE                       S10_1678              S10_1678
# CUSTOMERNAME      Corporate Gift Ideas Co.  Technics Stores Inc.
# PHONE                           6505551386            6505556809
# ADDRESSLINE1               7734 Strong St.     9408 Furth Circle
# ADDRESSLINE2                           NaN                   NaN
# CITY                         San Francisco            Burlingame
# STATE                                   CA                    CA
# POSTALCODE                             NaN                 94217
# COUNTRY                                USA                   USA
# TERRITORY                              NaN                   NaN
# CONTACTLASTNAME                      Brown                Hirano
# CONTACTFIRSTNAME                     Julie                  Juri
# DEALSIZE                            Medium                Medium
#
#                                          6                            7  \
# ORDERNUMBER                          10180                        10188
# QUANTITYORDERED                         29                           48
# PRICEEACH                            86.13                        100.0
# ORDERLINENUMBER                          9                            1
# SALES                              2497.77                      5512.32
# ORDERDATE                  11/11/2003 0:00              11/18/2003 0:00
# STATUS                             Shipped                      Shipped
# QTR_ID                                   4                            4
# MONTH_ID                                11                           11
# YEAR_ID                               2003                         2003
# PRODUCTLINE                    Motorcycles                  Motorcycles
# MSRP                                    95                           95
# PRODUCTCODE                       S10_1678                     S10_1678
# CUSTOMERNAME      Daedalus Designs Imports                 Herkku Gifts
# PHONE                           20.16.1555                +47 2267 3215
# ADDRESSLINE1       184, chausse de Tournai  Drammen 121, PR 744 Sentrum
# ADDRESSLINE2                           NaN                          NaN
# CITY                                 Lille                       Bergen
# STATE                                  NaN                          NaN
# POSTALCODE                           59000                       N 5804
# COUNTRY                             France                       Norway
# TERRITORY                             EMEA                         EMEA
# CONTACTLASTNAME                      Rance                       Oeztan
# CONTACTFIRSTNAME                   Martine                       Veysel
# DEALSIZE                             Small                       Medium
#
#                                           8                  9
# ORDERNUMBER                           10201              10211
# QUANTITYORDERED                          22                 41
# PRICEEACH                             98.57              100.0
# ORDERLINENUMBER                           2                 14
# SALES                               2168.54            4708.44
# ORDERDATE                    12/1/2003 0:00     1/15/2004 0:00
# STATUS                              Shipped            Shipped
# QTR_ID                                    4                  1
# MONTH_ID                                 12                  1
# YEAR_ID                                2003               2004
# PRODUCTLINE                     Motorcycles        Motorcycles
# MSRP                                     95                 95
# PRODUCTCODE                        S10_1678           S10_1678
# CUSTOMERNAME                Mini Wheels Co.   Auto Canal Petit
# PHONE                            6505555787     (1) 47.55.6555
# ADDRESSLINE1      5557 North Pendale Street  25, rue Lauriston
# ADDRESSLINE2                            NaN                NaN
# CITY                          San Francisco              Paris
# STATE                                    CA                NaN
# POSTALCODE                              NaN              75016
# COUNTRY                                 USA             France
# TERRITORY                               NaN               EMEA
# CONTACTLASTNAME                      Murphy            Perrier
# CONTACTFIRSTNAME                      Julie          Dominique
# DEALSIZE                              Small             Medium

# %% [markdown]
# We won't be doing a lot of EDA here since EDA has been done using SQL.
#
# But we'll have to clean our data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  ADDRESSLINE2      302 non-null    object
#  17  CITY              2823 non-null   object
#  18  STATE             1337 non-null   object
#  19  POSTALCODE        2747 non-null   object
#  20  COUNTRY           2823 non-null   object
#  21  TERRITORY         1749 non-null   object
#  22  CONTACTLASTNAME   2823 non-null   object
#  23  CONTACTFIRSTNAME  2823 non-null   object
#  24  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 551.5+ KB

# %%
data = data.drop('ADDRESSLINE2', axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
#  16  CITY              2823 non-null   object
#  17  STATE             1337 non-null   object
#  18  POSTALCODE        2747 non-null   object
#  19  COUNTRY           2823 non-null   object
#  20  TERRITORY         1749 non-null   object
#  21  CONTACTLASTNAME   2823 non-null   object
#  22  CONTACTFIRSTNAME  2823 non-null   object
#  23  DEALSIZE          2823 non-null   object
# dtypes: float64(2), int64(7), object(15)
# memory usage: 529.4+ KB

# %%
data['ORDERDATE']
# Out:
# 0        2/24/2003 0:00
# 1         5/7/2003 0:00
# 2         7/1/2003 0:00
# 3        8/25/2003 0:00
# 4       10/10/2003 0:00
#              ...
# 2818     12/2/2004 0:00
# 2819     1/31/2005 0:00
# 2820      3/1/2005 0:00
# 2821     3/28/2005 0:00
# 2822      5/6/2005 0:00
# Name: ORDERDATE, Length: 2823, dtype: object

# %%
data["ORDERDATE"] = data["ORDERDATE"].apply(lambda x: x.split(' ')[0])
data["ORDERDATE"].head()
# Out:
# 0     2/24/2003
# 1      5/7/2003
# 2      7/1/2003
# 3     8/25/2003
# 4    10/10/2003
# Name: ORDERDATE, dtype: object

# %%
data["ORDERDATE"] = data["ORDERDATE"].apply(lambda x: datetime.strptime(x, '%m/%d/%Y'))

# %%
data["ORDERDATE"].head()
# Out:
# 0   2003-02-24
# 1   2003-05-07
# 2   2003-07-01
# 3   2003-08-25
# 4   2003-10-10
# Name: ORDERDATE, dtype: datetime64[ns]

# %%
data.head().T
# Out:
#                                         0                    1  \
# ORDERNUMBER                         10107                10121
# QUANTITYORDERED                        30                   34
# PRICEEACH                            95.7                81.35
# ORDERLINENUMBER                         2                    5
# SALES                              2871.0               2765.9
# ORDERDATE             2003-02-24 00:00:00  2003-05-07 00:00:00
# STATUS                            Shipped              Shipped
# QTR_ID                                  1                    2
# MONTH_ID                                2                    5
# YEAR_ID                              2003                 2003
# PRODUCTLINE                   Motorcycles          Motorcycles
# MSRP                                   95                   95
# PRODUCTCODE                      S10_1678             S10_1678
# CUSTOMERNAME            Land of Toys Inc.   Reims Collectables
# PHONE                          2125557818           26.47.1555
# ADDRESSLINE1      897 Long Airport Avenue   59 rue de l'Abbaye
# CITY                                  NYC                Reims
# STATE                                  NY                  NaN
# POSTALCODE                          10022                51100
# COUNTRY                               USA               France
# TERRITORY                             NaN                 EMEA
# CONTACTLASTNAME                        Yu              Henriot
# CONTACTFIRSTNAME                     Kwai                 Paul
# DEALSIZE                            Small                Small
#
#                                               2                    3  \
# ORDERNUMBER                               10134                10145
# QUANTITYORDERED                              41                   45
# PRICEEACH                                 94.74                83.26
# ORDERLINENUMBER                               2                    6
# SALES                                   3884.34               3746.7
# ORDERDATE                   2003-07-01 00:00:00  2003-08-25 00:00:00
# STATUS                                  Shipped              Shipped
# QTR_ID                                        3                    3
# MONTH_ID                                      7                    8
# YEAR_ID                                    2003                 2003
# PRODUCTLINE                         Motorcycles          Motorcycles
# MSRP                                         95                   95
# PRODUCTCODE                            S10_1678             S10_1678
# CUSTOMERNAME                    Lyon Souveniers    Toys4GrownUps.com
# PHONE                          +33 1 46 62 7555           6265557265
# ADDRESSLINE1      27 rue du Colonel Pierre Avia   78934 Hillside Dr.
# CITY                                      Paris             Pasadena
# STATE                                       NaN                   CA
# POSTALCODE                                75508                90003
# COUNTRY                                  France                  USA
# TERRITORY                                  EMEA                  NaN
# CONTACTLASTNAME                        Da Cunha                Young
# CONTACTFIRSTNAME                         Daniel                Julie
# DEALSIZE                                 Medium               Medium
#
#                                          4
# ORDERNUMBER                          10159
# QUANTITYORDERED                         49
# PRICEEACH                            100.0
# ORDERLINENUMBER                         14
# SALES                              5205.27
# ORDERDATE              2003-10-10 00:00:00
# STATUS                             Shipped
# QTR_ID                                   4
# MONTH_ID                                10
# YEAR_ID                               2003
# PRODUCTLINE                    Motorcycles
# MSRP                                    95
# PRODUCTCODE                       S10_1678
# CUSTOMERNAME      Corporate Gift Ideas Co.
# PHONE                           6505551386
# ADDRESSLINE1               7734 Strong St.
# CITY                         San Francisco
# STATE                                   CA
# POSTALCODE                             NaN
# COUNTRY                                USA
# TERRITORY                              NaN
# CONTACTLASTNAME                      Brown
# CONTACTFIRSTNAME                     Julie
# DEALSIZE                            Medium

# %%
data[['CUSTOMERNAME', 'SALES', 'ORDERDATE']]
# Out:
#                   CUSTOMERNAME    SALES  ORDERDATE
# 0            Land of Toys Inc.  2871.00 2003-02-24
# 1           Reims Collectables  2765.90 2003-05-07
# 2              Lyon Souveniers  3884.34 2003-07-01
# 3            Toys4GrownUps.com  3746.70 2003-08-25
# 4     Corporate Gift Ideas Co.  5205.27 2003-10-10
# ...                        ...      ...        ...
# 2818     Euro Shopping Channel  2244.40 2004-12-02
# 2819   Oulu Toy Supplies, Inc.  3978.51 2005-01-31
# 2820     Euro Shopping Channel  5417.57 2005-03-01
# 2821              Alpha Cognac  2116.16 2005-03-28
# 2822         Gifts4AllAges.com  3079.44 2005-05-06
#
# [2823 rows x 3 columns]

# %%
customer_data = data[['CUSTOMERNAME', 'SALES', 'ORDERDATE']]

# %%
customer_data.head()
# Out:
#                CUSTOMERNAME    SALES  ORDERDATE
# 0         Land of Toys Inc.  2871.00 2003-02-24
# 1        Reims Collectables  2765.90 2003-05-07
# 2           Lyon Souveniers  3884.34 2003-07-01
# 3         Toys4GrownUps.com  3746.70 2003-08-25
# 4  Corporate Gift Ideas Co.  5205.27 2003-10-10

# %%
monetary_df = data.groupby(by='CUSTOMERNAME', as_index=False)['SALES'].sum()

# %%
monetary_df.columns = ['CUSTOMERNAME', 'Monetary']
monetary_df.head()
# Out:
#               CUSTOMERNAME   Monetary
# 0           AV Stores, Co.  157807.81
# 1             Alpha Cognac   70488.44
# 2       Amica Models & Co.   94117.26
# 3  Anna's Decorations, Ltd  153996.13
# 4        Atelier graphique   24179.96

# %%
monetary_df.shape
# Out:
# (92, 2)

# %%
recency_df = data.groupby(by='CUSTOMERNAME',
                        as_index=False)['ORDERDATE'].max()


recency_df.columns = ['CUSTOMERNAME', 'LastPurchaseDate']
recent_date = recency_df['LastPurchaseDate'].max()

# %%
recency_df['Recency'] = recency_df['LastPurchaseDate'].apply(
    lambda x: (recent_date - x).days)
recency_df.head()
# Out:
#               CUSTOMERNAME LastPurchaseDate  Recency
# 0           AV Stores, Co.       2004-11-17      195
# 1             Alpha Cognac       2005-03-28       64
# 2       Amica Models & Co.       2004-09-09      264
# 3  Anna's Decorations, Ltd       2005-03-09       83
# 4        Atelier graphique       2004-11-25      187

# %%
recency_df.shape
# Out:
# (92, 3)

# %%
frequency_df = data.drop_duplicates().groupby(
    by=['CUSTOMERNAME'], as_index=False)['ORDERDATE'].count()

frequency_df.columns = ['CUSTOMERNAME', 'Frequency']

# %%
frequency_df.head()
# Out:
#               CUSTOMERNAME  Frequency
# 0           AV Stores, Co.         51
# 1             Alpha Cognac         20
# 2       Amica Models & Co.         26
# 3  Anna's Decorations, Ltd         46
# 4        Atelier graphique          7

# %%
frequency_df.shape
# Out:
# (92, 2)

# %%
frequency_df[frequency_df['Frequency']==frequency_df['Frequency'].max()]
# Out:
#              CUSTOMERNAME  Frequency
# 33  Euro Shopping Channel        259

# %%
data['CUSTOMERNAME'].value_counts()
# Out:
# Euro Shopping Channel           259
# Mini Gifts Distributors Ltd.    180
# Australian Collectors, Co.       55
# La Rochelle Gifts                53
# AV Stores, Co.                   51
#                                ...
# Microscale Inc.                  10
# Royale Belge                      8
# Auto-Moto Classics Inc.           8
# Atelier graphique                 7
# Boards & Toys Co.                 3
# Name: CUSTOMERNAME, Length: 92, dtype: int64

# %%
rf_df = recency_df.merge(frequency_df, on='CUSTOMERNAME')

# %%
rf_df.head()
# Out:
#               CUSTOMERNAME LastPurchaseDate  Recency  Frequency
# 0           AV Stores, Co.       2004-11-17      195         51
# 1             Alpha Cognac       2005-03-28       64         20
# 2       Amica Models & Co.       2004-09-09      264         26
# 3  Anna's Decorations, Ltd       2005-03-09       83         46
# 4        Atelier graphique       2004-11-25      187          7

# %%
monetary_df.head()
# Out:
#               CUSTOMERNAME   Monetary
# 0           AV Stores, Co.  157807.81
# 1             Alpha Cognac   70488.44
# 2       Amica Models & Co.   94117.26
# 3  Anna's Decorations, Ltd  153996.13
# 4        Atelier graphique   24179.96

# %%
rfm_df = rf_df.merge(monetary_df, on='CUSTOMERNAME').drop(
    columns='LastPurchaseDate')


rfm_df.head()
# Out:
#               CUSTOMERNAME  Recency  Frequency   Monetary
# 0           AV Stores, Co.      195         51  157807.81
# 1             Alpha Cognac       64         20   70488.44
# 2       Amica Models & Co.      264         26   94117.26
# 3  Anna's Decorations, Ltd       83         46  153996.13
# 4        Atelier graphique      187          7   24179.96

# %%
rfm_df['R_rank'] = rfm_df['Recency'].rank(ascending=False)
rfm_df['F_rank'] = rfm_df['Frequency'].rank(ascending=True)
rfm_df['M_rank'] = rfm_df['Monetary'].rank(ascending=True)

# %%
rfm_df.head()
# Out:
#               CUSTOMERNAME  Recency  Frequency   Monetary  R_rank  F_rank  \
# 0           AV Stores, Co.      195         51  157807.81    39.5    88.0
# 1             Alpha Cognac       64         20   70488.44    71.0    26.0
# 2       Amica Models & Co.      264         26   94117.26    17.0    50.0
# 3  Anna's Decorations, Ltd       83         46  153996.13    68.0    83.5
# 4        Atelier graphique      187          7   24179.96    46.0     2.0
#
#    M_rank
# 0    84.0
# 1    24.0
# 2    52.0
# 3    83.0
# 4     2.0

# %%
# normalizing the rank of the customers
rfm_df['R_rank_norm'] = (rfm_df['R_rank']/rfm_df['R_rank'].max())*100
rfm_df['F_rank_norm'] = (rfm_df['F_rank']/rfm_df['F_rank'].max())*100
rfm_df['M_rank_norm'] = (rfm_df['F_rank']/rfm_df['M_rank'].max())*100

# %%
rfm_df.drop(columns=['R_rank', 'F_rank', 'M_rank'], inplace=True)

# %%
rfm_df.head()
# Out:
#               CUSTOMERNAME  Recency  Frequency   Monetary  R_rank_norm  \
# 0           AV Stores, Co.      195         51  157807.81    43.169399
# 1             Alpha Cognac       64         20   70488.44    77.595628
# 2       Amica Models & Co.      264         26   94117.26    18.579235
# 3  Anna's Decorations, Ltd       83         46  153996.13    74.316940
# 4        Atelier graphique      187          7   24179.96    50.273224
#
#    F_rank_norm  M_rank_norm
# 0    95.652174    95.652174
# 1    28.260870    28.260870
# 2    54.347826    54.347826
# 3    90.760870    90.760870
# 4     2.173913     2.173913

# %% [markdown]
#  **Consolidated Score = 0.15*R_rank_norm + 0.28*F_rank_norm + 0.57M_rank_norm**

# %%
rfm_df['RFM_Score'] = 0.15*rfm_df['R_rank_norm']+0.28 * \
    rfm_df['F_rank_norm']+0.57*rfm_df['M_rank_norm']

rfm_df['RFM_Score'] *= 0.05

# %%
rfm_df = rfm_df.round(2)

# %%
rfm_df.head()
# Out:
#               CUSTOMERNAME  Recency  Frequency   Monetary  R_rank_norm  \
# 0           AV Stores, Co.      195         51  157807.81        43.17
# 1             Alpha Cognac       64         20   70488.44        77.60
# 2       Amica Models & Co.      264         26   94117.26        18.58
# 3  Anna's Decorations, Ltd       83         46  153996.13        74.32
# 4        Atelier graphique      187          7   24179.96        50.27
#
#    F_rank_norm  M_rank_norm  RFM_Score
# 0        95.65        95.65       4.39
# 1        28.26        28.26       1.78
# 2        54.35        54.35       2.45
# 3        90.76        90.76       4.41
# 4         2.17         2.17       0.47

# %% [markdown]
#  1.     rfm_score >4.5 :   Top Customer
#  2.     4.5 > rfm_score > 4 : High Value Customer
#  3.     4> rfm_score >3 : Medium value customer
#  4.     3> rfm_score >1.6 : Low-value customer
#  5.     rfm_score <1.6 :Lost Customer

# %%
rfm_df["Customer_segment"] = np.where(rfm_df['RFM_Score'] > 4.5, "Top Customers",
                            (np.where( rfm_df['RFM_Score'] > 4,"High value Customer",
                            (np.where( rfm_df['RFM_Score'] > 3, "Medium Value Customer",
                             np.where(rfm_df['RFM_Score'] > 1.6,'Low Value Customers', 'Lost Customers'))))))

# %%
new_rfm_df = rfm_df[['CUSTOMERNAME', 'RFM_Score', 'Customer_segment', 'Recency', 'Frequency', 'Monetary']]

# %%
new_rfm_df.head(10)
# Out:
#                    CUSTOMERNAME  RFM_Score       Customer_segment  Recency  \
# 0                AV Stores, Co.       4.39    High value Customer      195
# 1                  Alpha Cognac       1.78    Low Value Customers       64
# 2            Amica Models & Co.       2.45    Low Value Customers      264
# 3       Anna's Decorations, Ltd       4.41    High value Customer       83
# 4             Atelier graphique       0.47         Lost Customers      187
# 5  Australian Collectables, Ltd       2.37    Low Value Customers       22
# 6    Australian Collectors, Co.       4.55          Top Customers      183
# 7   Australian Gift Network, Co       1.15         Lost Customers      118
# 8            Auto Assoc. & Cie.       1.08         Lost Customers      232
# 9              Auto Canal Petit       3.19  Medium Value Customer       54
#
#    Frequency   Monetary
# 0         51  157807.81
# 1         20   70488.44
# 2         26   94117.26
# 3         46  153996.13
# 4          7   24179.96
# 5         23   64591.46
# 6         55  200995.41
# 7         15   59469.12
# 8         18   64834.32
# 9         27   93170.66

# %%
new_rfm_df.groupby(by='Customer_segment',as_index=False)['Frequency'].sum()
# Out:
#         Customer_segment  Frequency
# 0    High value Customer        596
# 1         Lost Customers        376
# 2    Low Value Customers        749
# 3  Medium Value Customer        509
# 4          Top Customers        593

# %%
merged_data = pd.merge(data, new_rfm_df, on=['CUSTOMERNAME'], how='inner')

# %%
merged_data['CUSTOMERNAME'].value_counts()
# Out:
# Euro Shopping Channel           259
# Mini Gifts Distributors Ltd.    180
# Australian Collectors, Co.       55
# La Rochelle Gifts                53
# AV Stores, Co.                   51
#                                ...
# Microscale Inc.                  10
# Royale Belge                      8
# Auto-Moto Classics Inc.           8
# Atelier graphique                 7
# Boards & Toys Co.                 3
# Name: CUSTOMERNAME, Length: 92, dtype: int64

# %%
merged_data['Customer_segment'].value_counts()
# Out:
# Low Value Customers      749
# High value Customer      596
# Top Customers            593
# Medium Value Customer    509
# Lost Customers           376
# Name: Customer_segment, dtype: int64

# %%
merged_data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10329               42     100.00                1  4396.14
# 2        10107               39      99.91                5  3896.49
# 3        10329               20     100.00                2  3176.00
# 4        10107               27     100.00                4  6065.55
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... COUNTRY  TERRITORY  \
# 0 2003-02-24  Shipped       1         2     2003  ...     USA        NaN
# 1 2004-11-15  Shipped       4        11     2004  ...     USA        NaN
# 2 2003-02-24  Shipped       1         2     2003  ...     USA        NaN
# 3 2004-11-15  Shipped       4        11     2004  ...     USA        NaN
# 4 2003-02-24  Shipped       1         2     2003  ...     USA        NaN
#
#   CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE RFM_Score     Customer_segment  \
# 0              Yu             Kwai    Small      4.32  High value Customer
# 1              Yu             Kwai   Medium      4.32  High value Customer
# 2              Yu             Kwai   Medium      4.32  High value Customer
# 3              Yu             Kwai   Medium      4.32  High value Customer
# 4              Yu             Kwai   Medium      4.32  High value Customer
#
#   Recency Frequency   Monetary
# 0     197        49  164069.44
# 1     197        49  164069.44
# 2     197        49  164069.44
# 3     197        49  164069.44
# 4     197        49  164069.44
#
# [5 rows x 29 columns]

# %%
merged_data.to_csv('data/sample_data_sample_RFM.csv', index=False)

# %%
data_new = pd.read_csv("data/sample_data_sample_RFM.csv")
data_new.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10329               42     100.00                1  4396.14
# 2        10107               39      99.91                5  3896.49
# 3        10329               20     100.00                2  3176.00
# 4        10107               27     100.00                4  6065.55
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... COUNTRY  TERRITORY  \
# 0  2003-02-24  Shipped       1         2     2003  ...     USA        NaN
# 1  2004-11-15  Shipped       4        11     2004  ...     USA        NaN
# 2  2003-02-24  Shipped       1         2     2003  ...     USA        NaN
# 3  2004-11-15  Shipped       4        11     2004  ...     USA        NaN
# 4  2003-02-24  Shipped       1         2     2003  ...     USA        NaN
#
#   CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE RFM_Score     Customer_segment  \
# 0              Yu             Kwai    Small      4.32  High value Customer
# 1              Yu             Kwai   Medium      4.32  High value Customer
# 2              Yu             Kwai   Medium      4.32  High value Customer
# 3              Yu             Kwai   Medium      4.32  High value Customer
# 4              Yu             Kwai   Medium      4.32  High value Customer
#
#   Recency Frequency   Monetary
# 0     197        49  164069.44
# 1     197        49  164069.44
# 2     197        49  164069.44
# 3     197        49  164069.44
# 4     197        49  164069.44
#
# [5 rows x 29 columns]

# %%
data_new.groupby(by='Customer_segment',as_index=False)['Frequency'].sum()
# Out:
#         Customer_segment  Frequency
# 0    High value Customer      25694
# 1         Lost Customers       5962
# 2    Low Value Customers      18271
# 3  Medium Value Customer      16347
# 4          Top Customers     107431

# %%
pd.groupby()
